# %% [markdown]
# <a href="https://colab.research.google.com/github/zhaobelle/meaw/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("-----รายชื่อวัคซีนที่เปิดให้จอง-----") #แสดงข้อความรายชื่อวัคซีนที่เปิดให้จอง
vname = ["1.ไฟพูม", "2.แพทตร้า", "3.ซิโนกอล์ฟ"] #vnameคือ ลิสต์ของชื่อวัคซีน ภายในลิสต์จะมีวัคซีน3ยี่ห้อ
price = ["1500","1500","1500"] #price คือลิสต์ของราคาวัคซีน ภายในลิสต์จะมีราคาวัคซีน เข็มละ1500บาท
print("ชื่อวัคซีนและราคา") #แสดงข้อความชื่อวัคซีนและราคา
for i in vname: #i จะมีค่าเท่ากับข้อมูลในแต่ละลำดับของลิสต์ และ i in vname คือ ไฟพูม,แพทตร้า,ซิโนกอล์ฟ
  print(i,end="\t") #ให้แสดงข้อความในลิสต์ แล้วจบด้วย \t คือเว้นวรรค
print()

for i in price: #i จะมีค่าเท่ากับข้อมูลในแต่ละลำดับของลิสต์ และ i in price จะเป็นราคาของวัคซีน คือ 1500 บาทเท่ากันทั้ง 3 เข็ม
  print(i,end="\t") #ให้แสดงข้อความในลิสต์ แล้วจบด้วย \t คือเว้นวรรค
print()
print("-----------------------------") 


A = int(input("กรุณาเลือกวัคซีนตามหมายเลข: ")) #A ตัวแปร int คือ จำนวนเต็ม input คือการรับค่าจากผู้ใช้ ซึ่งสามารถรับค่าได้เฉพาะจำนวนเต็ม
vaccine = ["ไฟพูม","แพทตร้า","ซิโนกอล์ฟ"] #V คือลิสต์ ตัวแปรภายในลิสต์จะมีชื่อวัคซีน3ยี่ห้อ
if A==1: # ถ้า A เท่ากับ 1 ให้ทำคำสั่งต่อไปนี้
  print("วัคซีนที่คุณเลือกคือ", v[0]) #ให้แสดง วัคซีนที่คุณเลือกคือ และv[0]เป็นการอ้างถึงลิสต์ลำดับที่0 ก็คือวัคซีนไฟพูม
elif A==2: # ถ้า A เท่ากับ 2 ให้ทำคำสั่งต่อไปนี้
  print("วัคซีนที่คุณเลือกคือ", v[1]) #ให้แสดง วัคซีนที่คุณเลือกคือ และv[1]เป็นการอ้างถึงลิสต์ลำดับที่1 ก็คือวัคซีนแพทตร้า
elif A==3: # ถ้า A เท่ากับ 3 ให้ทำคำสั่งต่อไปนี้
  print("วัคซีนที่คุณเลือกคือ", v[2]) #ให้แสดง วัคซีนที่คุณเลือกคือ และv[2]เป็นการอ้างถึงลิสต์ลำดับที่2 ก็คือวัคซีนซิโนกอล์ฟ
print("-----------------------------")

L = ["เหรียญ","ธนบัตร"] # L คือลิสต์ ตัวแปรภายในลิสต์ L จะมีเหรียญและธนบัตร
print("1.เหรียญ\n2.ธนบัตร") #แสดงข้อความ 1.เหรียญ \n คือการขึ้นบรรทัดใหม่ 2.ธนบัตร
print("*หมายเหตุ มีคิดค่าบริการ200บาท") #แสดงข้อความ *หมายเหตุ มีคิดค่าบริการ200บาท
print("-----------------------------")

def fee(n):  #def คือการบอกว่าจะสร้างฟังก์ชัน fee คือชื่อของฟังก์ชัน (n) คือ input ของฟังก์ชัน
  c = 1500+200 #เป็นตัวแฟรที่กำหนดค่าเอาไว้
  return c  #return c คือ มีการคืนค่า c c คือ 1500+200

H = int(input("กรุณาเลือกช่องทางการชำระเงิน: ")) # int คือจำนวนเต็ม input คือรับค่าจากผู้ใช้ 
if H==1: #ถ้า H เท่ากับ 1 ให้ทำคำสั่งต่อไปนี้
    print("สรุปยอดเงิน =",fee('n'),"บาท") #ให้แสดงข้อความสรุปยอดเงิน และมีการเรียกใช้ฟังก์ชัน
else: 
  H==2 #ถ้า H เท่ากับ 2 ให้ทำคำสั่งต่อไปนี้
  print("สรุปยอดเงิน =",fee('n'),"บาท") #ให้แสดงข้อความสรุปยอดเงิน และมีการเรียกใช้ฟังก์ชัน
# Out:
# -----รายชื่อวัคซีนที่เปิดให้จอง-----
# ชื่อวัคซีนและราคา
# 1.ไฟพูม	2.แพทตร้า	3.ซิโนกอล์ฟ
# 1500	1500	1500
# -----------------------------
# กรุณาเลือกวัคซีนตามหมายเลข: 1
# วัคซีนที่คุณเลือกคือ ไฟพูม
# -----------------------------
# 1.เหรียญ
# 2.ธนบัตร
# *หมายเหตุ มีคิดค่าบริการ200บาท
# -----------------------------
# กรุณาเลือกช่องทางการชำระเงิน: 2
# สรุปยอดเงิน = 1700 บาท
